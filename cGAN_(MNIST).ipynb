# %%
import torch
import torchvision
import torch.nn as nn
from torchvision import transforms, datasets, models
from torchvision.utils import save_image
import os

# %%
device = torch.device('cuda' if torch.cuda.is_available else 'cpu')

# %%
learning_rate= 0.0002
batch_size = 100
num_epochs = 30
n_noise = 100

# %%
sample_dir = 'samples'

if not os.path.exists(sample_dir):
  os.makedirs(sample_dir)

# %%
transform = transforms.Compose([transforms.ToTensor()])

dataset = datasets.MNIST(root='../../data/', train=True, transform=transform, download=True)
data_loader = torch.utils.data.DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True)
# Out:
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../../data/MNIST/raw/train-images-idx3-ubyte.gz
# 9920512it [00:00, 19429132.16it/s]
# Extracting ../../data/MNIST/raw/train-images-idx3-ubyte.gz
# 32768it [00:00, 327904.69it/s]
# 0it [00:00, ?it/s]
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../../data/MNIST/raw/train-labels-idx1-ubyte.gz
# Extracting ../../data/MNIST/raw/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../../data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 1654784it [00:00, 5309571.96it/s]
# 8192it [00:00, 118131.54it/s]
# Extracting ../../data/MNIST/raw/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# Extracting ../../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!

# %%
def to_onehot(y, num_classes=10):
  y = y.long().cpu()    # input y.shape = (batch.size, 1)
  out = torch.LongTensor(y.size(0), num_classes)
  out.zero_()
  out.scatter_(1, y, 1)
  return out.float().to(device) #

# %%
class Discriminator(nn.Module):
  def __init__(self):
    super(Discriminator, self).__init__()
    self.layer1 = nn.Sequential(nn.Linear(28*28 + 10, 512),
                                nn.ReLU(True),
                                nn.Linear(512, 256),
                                nn.ReLU(True),
                                nn.Linear(256, 1),
                                nn.Sigmoid())
  def forward(self, x, c):
    x = torch.cat([x, c], 1)
    out = self.layer1(x)
    return out
  
###################################################################
###################################################################

class Generator(nn.Module):
  def __init__(self):
    super(Generator, self).__init__()
    self.layer1 = nn.Sequential(nn.Linear(n_noise + 10, 256),
                                nn.LeakyReLU(0.2, True),
                                nn.Linear(256, 512),
                                nn.LeakyReLU(0.2, True),
                                nn.Linear(512, 28*28),
                                nn.Tanh())
    
  def forward(self, x, c):
    x = torch.cat([x, c], 1)
    out = self.layer1(x)
    return out

# %%
D = Discriminator().to(device)
G = Generator().to(device)

# %%
criterion = nn.BCELoss()
d_optimizer = torch.optim.Adam(D.parameters(), lr=learning_rate, betas=(0.5, 0.999))
g_optimizer = torch.optim.Adam(G.parameters(), lr=learning_rate, betas=(0.5, 0.999))

def zero_grad():
  d_optimizer.zero_grad()
  g_optimizer.zero_grad()
  
def norm(images):
  return images*2 - 1
  
def denorm(images):
  images = (images+1)/2
  return images.clamp(0,1)

# %%
for epoch in range(num_epochs):
  for i, (images, labels) in enumerate(data_loader):
    images = images.view(images.size(0), -1).to(device)
    images = norm(images)
    labels = labels.view(labels.size(0),-1).to(device)  # (1, batch_size) -> (batch_size, 1)
    labels = to_onehot(labels)
    
    
    real_labels = torch.ones(images.size(0), 1).to(device)
    fake_labels = torch.zeros(images.size(0), 1).to(device)
    #===================================================
    #                 Train Discriminator
    # ==================================================
    outputs = D(images, labels)
    d_loss_real = criterion(outputs, real_labels)
    
    z = torch.randn(images.size(0), n_noise).to(device)
    fake_image = G(z, labels)
    outputs = D(fake_image, labels)
    d_loss_fake = criterion(outputs, fake_labels)
    
    
    d_loss = d_loss_real + d_loss_fake
    
    zero_grad()
    d_loss.backward()
    d_optimizer.step()
    
    #===================================================
    #                 Train Generator
    # ==================================================
    z = torch.randn(images.size(0), n_noise).to(device)
    fake_image = G(z, labels)
    outputs_fake = D(fake_image, labels)
    g_loss = criterion(outputs_fake, real_labels)
    
    zero_grad()
    g_loss.backward()
    g_optimizer.step()
    
    
    if (i+1) % 200 == 0:
      print('Epoch [{}/{}], Step [{}/{}], d_loss {:.4f}, g_loss : {:.4f}'
            .format(epoch, num_epochs, i+1, len(data_loader), d_loss.item(), g_loss.item()))
      
    
  fake_image = fake_image.view(fake_image.size(0), 1, 28, 28)
  save_image(denorm(fake_image), os.path.join(sample_dir, 'fake_images={}.png'.format(str(epoch).zfill(2))))
# Out:
# Epoch [0/30], Step [200/600], d_loss 0.5015, g_loss : 1.6063
# Epoch [0/30], Step [400/600], d_loss 0.4332, g_loss : 2.8917
# Epoch [0/30], Step [600/600], d_loss 0.4114, g_loss : 2.7370
# Epoch [1/30], Step [200/600], d_loss 0.9204, g_loss : 0.5216
# Epoch [1/30], Step [400/600], d_loss 0.3354, g_loss : 2.5132
# Epoch [1/30], Step [600/600], d_loss 0.2958, g_loss : 2.6904
# Epoch [2/30], Step [200/600], d_loss 0.2528, g_loss : 3.5418
# Epoch [2/30], Step [400/600], d_loss 0.3182, g_loss : 2.6016
# Epoch [2/30], Step [600/600], d_loss 0.3070, g_loss : 2.5601
# Epoch [3/30], Step [200/600], d_loss 0.2251, g_loss : 4.4291
# Epoch [3/30], Step [400/600], d_loss 0.2380, g_loss : 3.3483
# Epoch [3/30], Step [600/600], d_loss 0.2966, g_loss : 3.2443
# Epoch [4/30], Step [200/600], d_loss 0.4909, g_loss : 2.6976
# Epoch [4/30], Step [400/600], d_loss 0.2397, g_loss : 2.7578
# Epoch [4/30], Step [600/600], d_loss 0.2898, g_loss : 2.4826
# Epoch [5/30], Step [200/600], d_loss 0.3957, g_loss : 4.4047
# Epoch [5/30], Step [400/600], d_loss 0.2713, g_loss : 3.5920
# Epoch [5/30], Step [600/600], d_loss 0.3088, g_loss : 5.0086
# Epoch [6/30], Step [200/600], d_loss 0.2631, g_loss : 3.7447
# Epoch [6/30], Step [400/600], d_loss 0.5156, g_loss : 3.5867
# Epoch [6/30], Step [600/600], d_loss 0.4132, g_loss : 2.0271
# Epoch [7/30], Step [200/600], d_loss 0.5187, g_loss : 4.1621
# Epoch [7/30], Step [400/600], d_loss 0.7552, g_loss : 3.9873
# Epoch [7/30], Step [600/600], d_loss 0.4265, g_loss : 3.1775
# Epoch [8/30], Step [200/600], d_loss 0.3589, g_loss : 3.2613
# Epoch [8/30], Step [400/600], d_loss 0.4750, g_loss : 2.9962
# Epoch [8/30], Step [600/600], d_loss 0.5567, g_loss : 2.8966
# Epoch [9/30], Step [200/600], d_loss 0.5566, g_loss : 3.3437
# Epoch [9/30], Step [400/600], d_loss 0.5822, g_loss : 3.7810
# Epoch [9/30], Step [600/600], d_loss 0.7509, g_loss : 3.2961
# Epoch [10/30], Step [200/600], d_loss 0.4894, g_loss : 2.5476
# Epoch [10/30], Step [400/600], d_loss 0.7143, g_loss : 2.6435
# Epoch [10/30], Step [600/600], d_loss 0.5425, g_loss : 2.4614
# Epoch [11/30], Step [200/600], d_loss 0.6345, g_loss : 1.9895
# Epoch [11/30], Step [400/600], d_loss 0.5310, g_loss : 2.0755
# Epoch [11/30], Step [600/600], d_loss 0.6261, g_loss : 2.4032
# Epoch [12/30], Step [200/600], d_loss 0.6954, g_loss : 2.5655
# Epoch [12/30], Step [400/600], d_loss 0.6361, g_loss : 2.4119
# Epoch [12/30], Step [600/600], d_loss 0.6917, g_loss : 1.5389
# Epoch [13/30], Step [200/600], d_loss 0.8536, g_loss : 1.2293
# Epoch [13/30], Step [400/600], d_loss 0.8591, g_loss : 2.9033
# Epoch [13/30], Step [600/600], d_loss 0.7479, g_loss : 1.4477
# Epoch [14/30], Step [200/600], d_loss 0.7644, g_loss : 1.8892
# Epoch [14/30], Step [400/600], d_loss 0.6581, g_loss : 1.8335
# Epoch [14/30], Step [600/600], d_loss 0.7030, g_loss : 1.7781
# Epoch [15/30], Step [200/600], d_loss 0.6741, g_loss : 1.6873
# Epoch [15/30], Step [400/600], d_loss 0.6637, g_loss : 2.1795
# Epoch [15/30], Step [600/600], d_loss 0.7713, g_loss : 1.8792
# Epoch [16/30], Step [200/600], d_loss 0.7430, g_loss : 1.9268
# Epoch [16/30], Step [400/600], d_loss 0.9436, g_loss : 2.2044
# Epoch [16/30], Step [600/600], d_loss 0.6694, g_loss : 1.8309
# Epoch [17/30], Step [200/600], d_loss 0.8439, g_loss : 1.5934
# Epoch [17/30], Step [400/600], d_loss 0.8190, g_loss : 2.0450
# Epoch [17/30], Step [600/600], d_loss 0.6619, g_loss : 2.0035
# Epoch [18/30], Step [200/600], d_loss 0.7042, g_loss : 1.8656
# Epoch [18/30], Step [400/600], d_loss 0.8237, g_loss : 1.4540
# Epoch [18/30], Step [600/600], d_loss 0.6714, g_loss : 1.6937
# Epoch [19/30], Step [200/600], d_loss 0.8323, g_loss : 2.2186
# Epoch [19/30], Step [400/600], d_loss 0.9024, g_loss : 1.9372
# Epoch [19/30], Step [600/600], d_loss 0.7401, g_loss : 1.6563
# Epoch [20/30], Step [200/600], d_loss 0.8821, g_loss : 1.5028
# Epoch [20/30], Step [400/600], d_loss 0.6807, g_loss : 1.4795
# Epoch [20/30], Step [600/600], d_loss 0.8157, g_loss : 1.2527
# Epoch [21/30], Step [200/600], d_loss 0.8459, g_loss : 1.6013
# Epoch [21/30], Step [400/600], d_loss 0.8006, g_loss : 1.2937
# Epoch [21/30], Step [600/600], d_loss 0.9081, g_loss : 1.0118
# Epoch [22/30], Step [200/600], d_loss 0.8580, g_loss : 1.6116
# Epoch [22/30], Step [400/600], d_loss 0.9021, g_loss : 1.1558
# Epoch [22/30], Step [600/600], d_loss 0.9258, g_loss : 1.7516
# Epoch [23/30], Step [200/600], d_loss 0.8703, g_loss : 1.6898
# Epoch [23/30], Step [400/600], d_loss 0.7581, g_loss : 1.1736
# Epoch [23/30], Step [600/600], d_loss 0.8358, g_loss : 2.3435
# Epoch [24/30], Step [200/600], d_loss 0.8241, g_loss : 1.3911
# Epoch [24/30], Step [400/600], d_loss 0.9614, g_loss : 1.6177
# Epoch [24/30], Step [600/600], d_loss 0.8794, g_loss : 1.3835
# Epoch [25/30], Step [200/600], d_loss 0.8507, g_loss : 1.5941
# Epoch [25/30], Step [400/600], d_loss 0.7879, g_loss : 1.4553
# Epoch [25/30], Step [600/600], d_loss 1.0535, g_loss : 2.0563
# Epoch [26/30], Step [200/600], d_loss 0.8620, g_loss : 1.8683
# Epoch [26/30], Step [400/600], d_loss 0.8515, g_loss : 1.7249
# Epoch [26/30], Step [600/600], d_loss 0.9351, g_loss : 1.3388
# Epoch [27/30], Step [200/600], d_loss 1.0264, g_loss : 1.2799
# Epoch [27/30], Step [400/600], d_loss 0.8834, g_loss : 1.6701
# Epoch [27/30], Step [600/600], d_loss 0.8130, g_loss : 1.5940
# Epoch [28/30], Step [200/600], d_loss 0.8651, g_loss : 1.5202
# Epoch [28/30], Step [400/600], d_loss 0.8587, g_loss : 1.5434
# Epoch [28/30], Step [600/600], d_loss 1.0839, g_loss : 2.1586
# Epoch [29/30], Step [200/600], d_loss 0.9030, g_loss : 1.4280
# Epoch [29/30], Step [400/600], d_loss 0.8862, g_loss : 1.5397
# Epoch [29/30], Step [600/600], d_loss 0.9421, g_loss : 1.5446

# %%
from matplotlib.pyplot import imshow, imsave
import numpy as np
def get_sample_image(G, n_noise=100):
    """
        save sample 100 images
    """
    img = np.zeros([280, 280])
    for j in range(10):
        c = torch.zeros([10, 10]).to(device)
        c[:, j] = 1
        z = torch.randn(10, n_noise).to(device)
        y_hat = G(z,c).view(10, 28, 28)
        result = y_hat.cpu().data.numpy()
        img[j*28:(j+1)*28] = np.concatenate([x for x in result], axis=-1)
    return img

# %%
G.eval()
imshow(get_sample_image(G, n_noise), cmap='gray')
